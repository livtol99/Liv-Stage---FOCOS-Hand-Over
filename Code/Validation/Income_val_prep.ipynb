# %% [markdown]
# # Preparation for User validation. Obtaining User's Job Titles and Income

# %% [markdown]
# - In this notebook, I am fetching the job titles and income of users via N-gram frequency analysis.
# - The notebook contains subsequent data cleaning of manually inspected job title files to prep for model comparison and user estimate validation
# - Final result here is the finished file of users and their job titles and income

# %%
import os
import re
import sys
import numpy as np
import pandas as pd
import matplotlib
import spacy
from collections import Counter
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import FrenchStemmer
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import TfidfVectorizer

import importlib
# Local application imports
sys.path.insert(0, '../Utility files')
import utils2
from utils2 import *

# %% [markdown]
# ### N-grams + frequency analysis

# %%
# # Load the dimension data

path = '/home/livtollanes/NewData/coordinates/dim_X/'
file = '/m1_dimx_users_bios.csv'
bios = pd.read_csv(path+file, index_col=0)

#Sort the df from high to low according to the first dimenion
bios = bios.sort_values(by='0', ascending=False)
#bios['follower_id'].nunique() #115079

# %% [markdown]
# #### Obtain the most frequent n-grams in bios

# %% [markdown]
# From bios:

# %%
importlib.reload(utils2)
# Usage:
all_descriptions = ' '.join(bios['description_cleantext'])
ngram_freq = utils2.get_ngram_freq(all_descriptions,n=1)


# Get the most common bigrams
#most_common_unigrams = ngram_freq.most_common(4000)

#Write the ngrams to csv
# importlib.reload(utils2)
# utils2.write_ngrams_to_csv(most_common_unigrams, 'unigrams.csv')
# utils2.write_ngrams_to_csv(most_common_bigrams, 'bigrams.csv')
# utils2.write_ngrams_to_csv(most_common_trigrams, 'trigrams.csv')
# utils2.write_ngrams_to_csv(unigrams_last1000, 'uni_last1000.csv')

# %% [markdown]
# ### Data soure 1: Filter bios based on ngrams from bios

# %% [markdown]
# - Here, I am filtering the user bios by looking for overlapping ngrams. The ngrams I use here stem from people's bios, so identifying the common ways of referring to a job title.
# - This is the ngram matching approach that yields the most amount of users, since it reflects people's everyday language.
# - Eventually, the final df from this part needs to be annotated, deleting poorly identified bios.

# %%
#Load the file containing all relevant ngrams
path = '/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/'
file = 'keywords_INSEE.csv'
job_titles = pd.read_csv(path+file, header=0)

# %%
#Preprocessing of the key word file

#rename columns
job_titles = job_titles.rename(columns={'n_gram': 'key_word', 'PCS_ESE_code': 'PCS_ESE'})

#Sort job titles alphabetically and drop unnecessary cols
job_titles = job_titles.sort_values('key_word')
job_titles = job_titles.drop('ngram', axis=1)
job_titles = job_titles.drop('count', axis=1)

#dropping the ocs category just for now. might add it later - if income validation is not enough
job_titles = job_titles.drop('pcs_category_numbers', axis=1)
job_titles = job_titles.drop('pcs_category_name', axis=1)

#Syarting with 547 rows (key words of different token size)

#Reformat NA cells and drop rows with no CS_ESE code 
job_titles['PCS_ESE_name'] = job_titles['PCS_ESE_name'].replace('Na', np.nan)
job_titles['PCS_ESE'] = job_titles['PCS_ESE'].replace('Na', np.nan)

job_titles = job_titles.dropna(subset=['PCS_ESE']) #Now we have 226 key words left. We started with 547 key words. 321 could not be matched with INSEE data. 


#Remove newline characters in the 'PCS_ESE_name' column
job_titles['PCS_ESE'] = job_titles['PCS_ESE'].replace('\n', ' ', regex=True)
job_titles['PCS_ESE'] = job_titles['PCS_ESE'].str.strip()


job_titles['PCS_ESE_name'] = job_titles['PCS_ESE_name'].replace('\n', ' ', regex=True)
job_titles['PCS_ESE_name'] = job_titles['PCS_ESE_name'].str.strip()

# %%
#Load the merged income data

#income
path = '/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/'
file = 'INSEE_merged.csv'
income = pd.read_csv(path+file, sep=",")

#make the codes lower case, to match between data sets
income = income.drop(income.columns[0], axis=1)
income['PCS_ESE'] = income['PCS_ESE'].str.lower()
income = income.sort_values('Salaire moyen en EQTP')

# %%
#Get the user bios - that later wil get added income
# # Load the data

path = '/home/livtollanes/NewData/coordinates/dim_X/'
file = '/m1_dimx_users_bios.csv'
bios = pd.read_csv(path+file, index_col=0)

#Sort the df according to the first dimenion
bios = bios.sort_values(by='0', ascending=False)

# %%
#Tokenize our bios and save all tokens in a new column
nltk.download('stopwords')
stop_words = set(stopwords.words('french'))

bios = utils2.tokenize_bios(bios, stop_words)

# Convert key words from strings to tuples in order to filter based on our predefined n-gram list
job_titles['titles'] = job_titles['key_word'].apply(lambda x: tuple(x.split()))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/livtollanes/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Create a list of job titles from which we will filter the bios
titles_list = job_titles['titles'].tolist()

# Include only the users that have bios with n_grams occurring in our job title list
filtered_bios = bios[bios['total_n_grams'].apply(lambda x: any(ng in x for ng in titles_list))].copy()

# Add a new column 'titles'
filtered_bios.loc[:, 'titles'] = filtered_bios['total_n_grams'].apply(lambda x: [ng for ng in titles_list if ng in x])

# %%
# Split the detected titles into their respective n size
importlib.reload(utils2)
filtered_bios['unigrams_detected'] = filtered_bios['titles'].apply(lambda x: utils2.separate_ngrams(x)['unigrams_detected'])
filtered_bios['bigrams_detected'] = filtered_bios['titles'].apply(lambda x: utils2.separate_ngrams(x)['bigrams_detected'])
filtered_bios['trigrams_detected'] = filtered_bios['titles'].apply(lambda x: utils2.separate_ngrams(x)['trigrams_detected'])

# %% [markdown]
# With our own key words, we end up with 17 782 rows (users) that have a bio that is in our list

# %%
# Add PCS_ESE codes to the file

#multiple rows per users, one per suggested title
import ast

# Convert string representation of list of tuples into actual list of tuples
#filtered_bios['titles'] = filtered_bios['titles'].apply(ast.literal_eval)

#Explode the 'titles' column
bios_exploded = filtered_bios.explode('titles')

# %%
#add  a PCS_ESE code per suggested title
# Convert all titles to lowercase
job_titles['titles'] = job_titles['titles'].apply(lambda x: tuple([i.lower() for i in x]))
bios_exploded['titles'] = bios_exploded['titles'].apply(lambda x: tuple([i.lower() for i in x]))

bios_exploded = bios_exploded.merge(job_titles, on='titles', how='left')

# %%
selected_columns = bios_exploded[['follower_id', '0', 'screen_name', 'description_cleantext', 'titles', 'key_word', 'PCS_ESE', 'PCS_ESE_name']]
selected_columns.head()
# Out:
#            follower_id         0   screen_name  \
# 0           4808491882  2.183514   bone_avocat
# 1            186103608  2.141388  Son_and_graf
# 2   712739777515233281  2.104645     makunesss
# 3  1175402702836248578  2.095480    MaleckArts
# 4             68796663  2.092969    LGClequipe
#
#                                                                                                                                         description_cleantext  \
# 0                            Avocat associé Moyersoen Avocats /droit du sport membre fondateur de l'AIAF & l'Association des Avocats en Droit du Sport # AADS
# 1                        Graphiste freelance de métier, j'ai décidé de mettre à mon panel de créations le design de kit sportif afin de vous les partager ici
# 2  coach sportif, ancien footballeur professionnel formé a @OM_Officiel , passé par @fciopofficiel  @nimesolympique  @uscl_football  @athleticomars @fcannecy
# 3                       Communication chez @PartoucheSport   Graphiste freelance, collab avec @estac_officiel @OpenSuddeFrance  @CABCLRUGBY @QRM @Sport360..
# 4                                                                                            journaliste @lequipe @Ligue2BKT @ToulouseFC et un peu de @MotoGP
#
#              titles       key_word PCS_ESE  \
# 0         (avocat,)         avocat    312a
# 1      (graphiste,)      graphiste    354a
# 2  (coach, sportif)  coach sportif    424a
# 3      (graphiste,)      graphiste    354a
# 4    (journaliste,)    journaliste    352a
#
#                                                 PCS_ESE_name
# 0                                                    Avocats
# 1                                       Artistes plasticiens
# 2  Moniteurs et éducateurs sportifs, sportifs professionnels
# 3                                       Artistes plasticiens
# 4                     Journalistes (y c. rédacteurs en chef)

# %%
#write to csv
#bios_exploded.to_csv('/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/source1_titles.csv', index = False)
#filtered_bios = pd.read_csv('/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/source1_titles.csv')


#Write to annotation csv
# # Select specific columns
# selected_columns = bios_exploded[['follower_id', '0', 'screen_name', 'description_cleantext', 'titles', 'key_word', 'PCS_ESE', 'PCS_ESE_name']]
# # Save to CSV
# selected_columns.to_csv('/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/annotations/source1.csv', index=False)

# %% [markdown]
# Now, the next step is to go over the bios, manually annotate them. Do the added titles match?

# %% [markdown]
# ### Data source 2: Add suggested PCS_ESE codes based on INSEE n_grams

# %% [markdown]
# - Here, I am using the Ngram matching approach based on ngrams from the income files. I only use this for the bios that have not already been matched with the outher ngram match approach (data source 1). this is because I assume they'll yield similar result and only add to the complexuty of the manual annotation process.
# - The df I obtain here must be manually inspected too, removing rows with unrealistic suggestions. I will do a first draft, and Pedro can finish the rest

# %%
#Obtain ngrams on the Insee data
#income
path = '/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/'
file = 'INSEE_merged.csv'
income = pd.read_csv(path+file, sep=",")

#make the codes lower case, to match between data sets
income = income.drop(income.columns[0], axis=1)
income['PCS_ESE'] = income['PCS_ESE'].str.lower()
income = income.sort_values('Salaire moyen en EQTP')

# %%
# Preprocess the job labels in the INSEE data and return tokens 
# We only want isngulars in the job titles
# Download the necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')

# Load the French language model
nlp = spacy.load('fr_core_news_sm')

#Apply the function to the 'total_n_grams' column
income['label_processed'] = income['label'].apply(lambda text: utils2.preprocess_text(text, nlp))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/livtollanes/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/livtollanes/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/livtollanes/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#filter the bios df to only include the rows where follower_ids is not already in filtered_bios
#this is in order to time optimise the process, and see if we can add some extra 
bios_non_captured = bios[~bios['follower_id'].isin(filtered_bios['follower_id'])]

bios_non_captured.shape # 97 250

# %%
#Get ngrams
income['ngrams'] = income['label_processed'].apply(lambda x: utils2.get_ngrams(x, 3))

# Convert n-grams to lists when creating the DataFrames
income['ngrams'] = income['ngrams'].apply(lambda x: [' '.join(tup) for tup in x])
bios_non_captured['total_n_grams'] = bios_non_captured['total_n_grams'].apply(lambda x: [' '.join(tup) for tup in x])

# Apply the function to each row in the 'bios' DataFrame
importlib.reload(utils2)
bios_non_captured['INSEE_suggested_PCS_ESE'] = bios_non_captured['total_n_grams'].apply(utils2.find_all_matches2, income_df=income)

#include only the ones that have a suggestion
bios_non_captured2 = bios_non_captured[bios_non_captured['INSEE_suggested_PCS_ESE'].apply(len) > 0]
# Out:
# /tmp/ipykernel_488208/249061574.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bios_non_captured['total_n_grams'] = bios_non_captured['total_n_grams'].apply(lambda x: [' '.join(tup) for tup in x])

# %%
s2 = pd.read_csv('/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/annotations/source2.csv')

# %%
# Rename 'INSEE_suggested_PCS_ESE' to 'PCS ESE'
s2_test = s2_test.rename(columns={'PCS_ESE': 'INSEE_suggested_PCS_ESE'})

# %%
s2_test.head()
# Out:
#    follower_id         0      screen_name  \
# 0    121394806  2.054530    aabarcaibarra
# 1   2962029519  2.026332         Dlamuray
# 2   2962029519  2.026332         Dlamuray
# 3   1174433185  1.966449  Dream_to_liveee
# 4    502038705  1.965581          GMau07L
#
#                                                                                                                                        description_cleantext  \
# 0      Chef de projet #digital et passionné par la #technologie et la manière dont elle peut changer le monde. #blackmirror.Pratique le #dodgeball à #Rennes
# 1  Responsable Commercial Normandie @TGS France / « Trouver des excuses pour ne pas faire est toujours plus facile que chercher des solutions pour réussir »
# 2  Responsable Commercial Normandie @TGS France / « Trouver des excuses pour ne pas faire est toujours plus facile que chercher des solutions pour réussir »
# 3                                                                                  26 ans, auxiliaire de puériculture, fan de foot & supportrice du @SMCaen
# 4                                                                                                                           Directeur Technique • FCCL • BEF
#
#   INSEE_suggested_PCS_ESE  \
# 0                    388c
# 1                    466b
# 2                    466a
# 3                    526c
# 4                    380a
#
#                                                                                                 label
# 0                                          Chefs de projets informatiques, responsables informatiques
# 1              Responsables commerciaux et administratifs des transports de marchandises (non cadres)
# 2  Responsables commerciaux et administratifs des transports de voyageurs et du tourisme (non cadres)
# 3                                                                         Auxiliaires de puériculture
# 4                                                       Directeurs techniques des grandes entreprises

# %%
#add  a PCS_ESE code per suggested title

# Rename 'INSEE_suggested_PCS_ESE' to 'PCS ESE'
s2 = s2.rename(columns={'INSEE_suggested_PCS_ESE': 'PCS_ESE'})
# Select 'PCS_ESE' and 'label' columns from 'income'
income_selected = income[['PCS_ESE', 'label']]

# Merge 's2' with the selected columns from 'income'
s2_test = s2.merge(income_selected, on='PCS_ESE', how='left')# Select 'PCS_ESE' and 'label' columns from 'income'

# Rename 'INSEE_suggested_PCS_ESE' to 'PCS ESE'
s2_test = s2_test.rename(columns={'PCS_ESE': 'INSEE_suggested_PCS_ESE'})

# %%
#add  a PCS_ESE code per suggested title
# Convert all titles to lowercase
job_titles['titles'] = job_titles['titles'].apply(lambda x: tuple([i.lower() for i in x]))
bios_exploded['titles'] = bios_exploded['titles'].apply(lambda x: tuple([i.lower() for i in x]))

bios_exploded = bios_exploded.merge(job_titles, on='titles', how='left')

# %%
#add one row per suggestion per user
bios_non_captured2 = bios_non_captured2.explode('INSEE_suggested_PCS_ESE')

#save source2 data to csv
bios_non_captured2.to_csv('/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/source2_titles.csv', index = False)

# %%
# Select specific columns
#selected_columns = s2[['follower_id', '0', 'screen_name', 'description_cleantext', 'INSEE_suggested_PCS_ESE']]

# Save to CSV
s2_test.to_csv('/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/annotations/source2.csv', index=False)

# %% [markdown]
# could potentially drop 388c. Chef de project - but some of them actually match.

# %% [markdown]
# ### Source 4: Manually identified users

# %% [markdown]
# Here, it is intended that I add the users that resulted from the manual inspection. These need to be properly annotated though

# %% [markdown]
# #### Manual inspection of bios - lower end focus

# %% [markdown]
# #so far, i've looked at the top 700 ones
# adter 700, i only included the ones that sounded unique - so the ones that did not mention owrds in our list

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
bios[['0', 'follower_id', 'screen_name', 'description_cleantext']].iloc[5000:5100]
# Out:
#                0          follower_id      screen_name  \
# 109295  1.562961           2247559753      FrostPlayer
# 106286  1.562960            734408245       MaeGameuZe
# 109103  1.562946   790830293540278272      Archange341
# 108888  1.562859           1499167418         n_attend
# 112008  1.562833            747896821     Potiron_Vert
# 112072  1.562673   939675719310946304         vallhe10
# 106569  1.562664           1031426233  _TacleALaGorge_
# 112132  1.562521            262686512        charloo44
# 108927  1.562433            142225944      dezphilippe
# 112507  1.562430   895736725418385409          sofloer
# 109001  1.562420           1357875554         MehdiNjd
# 110965  1.562419   940311226353111047          HugoRzN
# 112439  1.562413           3295178019     LeslieBigini
# 112033  1.562408   899421201596129280        MisterJR5
# 112335  1.562370            579832330  arbitrefootball
# 112422  1.562268  1397250979700092932       newson2K23
# 108461  1.562267           1225809008  Hurricane_Wiild
# 111692  1.562166           2996466604     stephakpl_22
# 111918  1.562159             83376016         sportpsy
# 108998  1.562041            608406360      florine_rvr
# 110966  1.562016           1924139114       Tonio__cze
# 108916  1.561987  1151992525076475904          enzoarn
# 106857  1.561920  1193550425330520065     TechandShoot
# 112437  1.561579   750380553287954432   jean_minassian
# 107508  1.561563  1193900804585000961     takumi_mugen
# 107022  1.561524  1055869330511052801   BoulAlexandre1
# 110683  1.561507           2577928942         boss8014
# 112518  1.561500           1451450430        Ch_Bureau
# 107688  1.561462   706243926580133888         AliiasGG
# 112068  1.561426            271987350         SportF24
# 111657  1.561380           2917737514  mickael_mouton6
# 111181  1.561343           2847880642        ZernoxYtb
# 111503  1.561197           2228797578      BassOussama
# 109986  1.561122           3242625861    gapp_illuZiOn
# 110301  1.561118             94641463          Tixy_22
# 110991  1.561115            315808826         Rom_Duch
# 107269  1.561110  1188540804068990978   davidguignery6
# 108222  1.561074            126898145        marinak89
# 107294  1.561023  1372534881486573571       ZokiGaming
# 106708  1.560988   725669362313613314         AkiraZFR
# 112308  1.560984             25872072     fannycarrier
# 111835  1.560975           4851604708         Klash_2K
# 112381  1.560972  1050480981004742658          vikcaen
# 111866  1.560925            946530960    SavastanoJoey
# 106481  1.560894   717091885114867713         VIClient
# 108684  1.560824           2163102377         Zero_974
# 108685  1.560824   770732360262414336     Memphishine_
# 109002  1.560792   736937562783223808          ninoxv3
# 109332  1.560668  1409853261457367042          KLinkry
# 111189  1.560618   769539157274271744  thomasquillien1
# 109620  1.560550            437680681       Ita1iano84
# 107139  1.560544           2251960921  Nasr_frenchtech
# 111721  1.560303  1540747691168104448  JulietteKirsc11
# 110750  1.560270            458485067     Frcalexandre
# 109394  1.560212  1147935170609197063       LaDrygance
# 112134  1.560161   899950747802009602       Pierrache4
# 112411  1.560092            626575638      antisocial1
# 106330  1.559948           1410364392         BkfPhoto
# 108861  1.559699   858353598455046145         pizano27
# 112479  1.559686            361222266    gaetcourtet18
# 109682  1.559619   835892034108014592        Chimorin_
# 110488  1.559602   878610080115163136      flavien1608
# 112374  1.559512  1043014049590521856    BoselliRomain
# 108324  1.559470            117084437        AnaelleeM
# 107153  1.559205   734038442376593408    liliansora174
# 112665  1.559143            636459286     LES_BOURRINS
# 107577  1.559141           2823082509     Manolocapo38
# 110067  1.558951            364212368     LoisonTanguy
# 112531  1.558926            304645314      gaupenicaud
# 106283  1.558918           2926634627       NtK_WANTED
# 107927  1.558875           1423921878          leo_sbn
# 106843  1.558874           1470729516      Whokimosabe
# 108524  1.558859  1063910960900042752       _fvalette7
# 107697  1.558824  1032374827141799936         Ghost72T
# 111419  1.558813           3037459419       tristaanx_
# 110303  1.558812            137448607        Jujuferey
# 110495  1.558641           4830737127        Mr_Dryzix
# 108479  1.558434            282052997       cyril62810
# 107266  1.558360   708928896813703168       Saitama_76
# 107265  1.558360   711646825682493440     AlexisHuet18
# 110855  1.558129  1160189046141833216         zamuus93
# 111022  1.558112            248190238       Luomastaps
# 109764  1.557961   737385494686904320          Guyyohm
# 107585  1.557935  1046334291733549056       anais_3706
# 106343  1.557823             94139371        Icaryjojo
# 106345  1.557823            316294299   LouiseChauloux
# 106344  1.557823            221842148       lucie61000
# 106448  1.557812            589293907         Elenwing
# 107904  1.557672   805751895902056448     Spartacle_78
# 111686  1.557510            485551615     MaximeSchell
# 107683  1.557504           4274404636     john09022017
# 109381  1.557455           3325515557        matfoot39
# 109359  1.557391            364791996         Yohan_Sm
# 112202  1.557224   906647085948264449        supakuala
# 111899  1.557178            261094022         kev_in57
# 108357  1.557132   899314401773309952       BarbarSaii
# 110394  1.556965   898298136535461888        patchekos
# 108167  1.556879  1484479779898277889      penaltyturf
# 107551  1.556855           2378881823          Frowke_
# 109913  1.556762             90139534        mroman085
#
#                                                                                                                                                    description_cleantext
# 109295                                                  Luis Enriqué : "Si une équipe peut nous mettre 4 buts alors on peut leur en mettre 6 avec l'aide de l'arbitre.."
# 106286                                                                                                              32 ans  Baigne dans les jeux vidéo depuis pitchoune
# 109103                                                                                             Bienvenue iciendroit sympa : https://urlz.fr/i0SNhttps://urlz.fr/i0SQ
# 108888                                                                   Mon rêve c'était d'être connu en faisant trembler San Siro -  #ACMilan #HeatNation #RavensFlock
# 112008                                                                                                                                            Supporter des verts !
# 112072                                   19 ans, fan de foot et de l'OM #TeamOM #TeamParieur Fan de #StrangerThings et de l'actrice Isabelle NantySnapchat : vlhermitte1
# 106569                                                                                                                                          Point faible: trop fort.
# 112132                                             Auxiliaire de viePetite fille d'agriculteursSupportrice du FC Nantes, abonnée en Loire.Team Déplacements #ActivNantes
# 108927                                                                                                                                                 Rien à déclarer..
# 112507                                                                  IDE complètement à l’Ouest . coup de foudre pour l’Andalousie et aussi le Portugal  team rando .
# 109001                                                                                                                   Vous ratez 100% des tirs que vous ne tentez pas
# 110965                                                                                                                                     Player on Xbox / Fan d’animé
# 112439                                                                                        Groupe Avindi @VSJBFC @mycoach_fr #Challenge #structuration #développement
# 112033                                                                                                                  Sport Football supporter de l'olympique lyonnais
# 112335                                                 http://arbitre-football.com est un site Internet totalement dédié aux arbitres de football de Fédéral à District.
# 112422                                                                                                                         Actualité, musique, astuce, story, vidéo
# 108461                        27 Years •  Superduke R  • Cannes (06) KTM 1290 2017 •  #TeamHurricane #TeamKTM #Teamicasque 15% remise "WILDBOY15" sur le site @icasque !
# 111692                                                                                                       Elles veulent un coup de foudre mais moi je suis un éclair.
# 111918  Psychologue du sport & Prépa mental pour sportifs/entraîneurs/parents http://psychologiesport.fr Podcast Gamberge https://bit.ly/3f4VUB #mental #sport #psysport
# 108998                                                     D'être autour d'une personne qui a de la chance c'est toujours une bénédiction, ça je vous le jure. @Amir_Off
# 110966                                                                                   supporter de l’ASSE  et d’Everton  #BleedGreen Daniel Ricciardo --- Journaliste
# 108916                                                                                                                           #KCORP fan des Guerriers de l'État doré
# 106857       Youtuber, avis et test de high tech, PC, photographie, vidéo Abonnés : 9KContact : techandshoot@outlook.frMa chaîne Youtube : http://bit.ly/2p4qKWI#GoTo10k
# 112437                                                                                                                     Conducteur de train #SNCF #TERNouvelleAQ  SPV
# 107508                        Fan de jeux vidéo (surtout de Kojima). j'aime la culture Japonaise. Joueur Xbox (series X) et Pc Je développe des jeux. Fanboy Dragon Ball
# 107022                                                                                                                                          C’est rien, c’est la rue
# 110683                                             Abonne toi si t'aime les jeux video. Et dites moi c'est koi votre PSN de PS3 comme sa on jouras ensemble aller BIS ;)
# 112518                                                                                                                Journaliste-Commentateur #Football #Natation #Boxe
# 107688                                                                                                                      Si tu te fais chier, tu sais ou me trouver !
# 112068                                        Suivez l'actualité du Sport avec @France24_fr ! @SportF24 vous fait vivre les plus grands événements sportifs en direct...
# 111657                                         Mickaël, 26 ans. Grenoblois  Journaliste de sport pour @OLPLAY_officiel  Amoureux de football  et de sport en tout genre
# 111181                                                       Lien de ma chaine youtube:Abonnez vous a ma chaine:https://www.youtube.com/channel/UCS6w1UVM8afSzVUjSA9xuyw
# 111503                                                                                                          bienvenue chez moi,Travaille chez Voiture plus puissante
# 109986                                                                                                                                             les malfaiteurs-TEAM
# 110301                                                                                           Fidèle supporter Guingampais, Kalon 48  #TEAMEAG Joueur  Golfeur  Papa
# 110991                                                                                             Dir. commercial LOSC Promotion, amoureux du sport et de la... vie! XD
# 107269                             j'aime la cuisine.d'aller au restaurant de regarder des vidéo sur Youtube et d'aller au cinéma de regarder des vidéo montage pc gamer
# 108222                                                                                                                                                         32 ans -
# 107294                                                                      Gamer dans l'âme ! Fan de jeux vidéos,de manga,d'anime,de sport et de bien d'autres choses !
# 106708                                                                                                                      L'art est dans l’œil de celui qui le regarde
# 112308                Coordinatrice sports de l'AFP pour le Grand Ouest. Passée par Lyon, Washington, Nicosie et Rome (forza Roma!). En partance pour Nice à la rentrée.
# 111835                                                                                                                      Joueur FIFA / milieux défensifs d’expérience
# 112381                                                                                                         supporter du sm caen, aime forcement les hauts et les bas
# 111866                          Pratiquant de l’Olympique Lyonnisme, Religion qui rend Malheureux. #OL #KVN #FekirFanAccount #BenArfaFanAccount    64eme d’un club de R2
# 106481                                                                                     Je twitte vos réclamations clients Partage de #bonplan #sav #experienceclient
# 108684                                                                                                                         TFT c'est quoi ça ?Natha pour les intimes
# 108685                                                 Le Goat de ce sport est bel est bien portugais, il s'appelle Joao Cancelo  Forza Juve  @juventusfc  @BrooklynNets
# 109002                                                                    la misère est si belle. encore et toujours le chemin du ROI. Neymar et Nuno mendes fan account
# 109332      La merveille est dans l'instant...    Ne pas Subir,Être et Durer !@UltrasAuxerre90 #TeamAJA @AjaEsports #FiersdetreAuxerrois #FiersdetreBleus @IF_Supporters
# 111189                                                                          je m'appelle thomas et je suis une personne handicapées et j'aime pleins de choses ... .
# 109620                                                                                                    Amateur de Sports en tout genre, d’humour et de second degré .
# 107139                                                  Passionné de #hightech et de nouvelles #technologies. En recherche d'#innovations  #Gameur à mes heures perdues
# 111721                                                                                                                                             Je suis très cordiale
# 110750                                                                                                                 vive les bordelais, chocolatine en force les amis
# 109394                                                                                                                               Éternel insatisfait  @AvaloneAgency
# 112134                                                                                         aime le sport et. le foot en particulier supporter du racing club de lens
# 112411                                                                                                                                           Lisez des livres bordel
# 106330                                                                                                                               photographier saisir l'âme des gens
# 108861                                                                                      « zone zone zone, bim bam boum, fille à fille » Valérie Garnier - 06/08/2021
# 112479                                                       Footballeur professionnel au FC LORIENT https://www.facebook.com/Gaetan-Courtet-Officielle-152216801499302/
# 109682                                                                                            SINJE   19yo  Personne pratiquant couramment le RT  Likeur de l'infini
# 110488                                                                                                     Vieux jeune à l'heure actuelle mais jeune vieux dans l'âme...
# 112374                                                                                                                                              Journaliste Europe 1
# 108324                                                                                                                                            28 ans. . Conceptrice
# 107153                                                                                                                                           passionné de jeux vidéo
# 112665                                                                                                             #communauté #fifa #nba at bourrins.eu  sur #pc#ligue1
# 107577                                                   Un grand pouvoir implique de grande responsabilité ! Supporter de @LFC                    YOU NEVER WALK ALONE
# 110067                                                                             Marseillais a la vie a la mort ! #ForzaOM ! #TeamOM #AJamaisLesPremiers #SW87 #Ultras
# 112531          Responsable des partenariats #Hospitalité #Sponsoring #Mécénat @RedStarFC / ex @PSG_inside ex @racing92 / Diplomé GE @Audencia 2013 / #Sport & #Business
# 106283       Entrepreneur - Twitch Partner - CEO @wantedssb & @tfsmash - Gros collectionneur de Pop culture et jeux vidéo et j'aime faire des expériences - contact : DM
# 107927                                                                                                            graphic designer, gauchiste, antiraciste, antifasciste
# 106843                                                                                                                         Nouvelles technologies. #DEVchezCarrefour
# 108524                                                                                                                     Ton électricien préféré   Je suis pas aigri !
# 107697                                                                                                Gamer passionné . Multi plateforme . Streameur un jour qui sait ..
# 111419                                                                                                                                               mieux que la drogue
# 110303                                                                                @girondins dans l'âme et cuisinier en cours de professionnalisation #teamGirondins
# 110495                                                                                                                                                      Le Vélodrome
# 108479                                                                                                                                        Joueur du rclens cecifoot
# 107266                                                                                                             un grand pouvoir implique de grandes responsabilités
# 107265                                                                       J'aime les jeux vidéos et YouTubeurs.Je suis YouTubeur Allez voir ma chaîne YouTube : Aleks
# 110855                                                                                                                                   fan de l’OM Nouvelle Calédonie
# 111022                                                                                                                Préparateur physique du Hockey Club Cergy Pontoise
# 109764                                                                                  FC Girondins de Bordeaux partout tout le tempsNew Orleans Pelicans  #WontBowDown
# 107585                                                                                              Anaïs, 23 ans, Tours - Chinon, faculté de Psychologie. Moto  gaming
# 106343                              Créatrice de contenu  / Community Manager Gameuse #PlayStation #Nintendo #PC #XboxPartage autour des jeux-vidéo et de la pop culture
# 106345                                                                                          Love life and music...  Bénévole pour l’association « Un Rêve à Vivre »
# 106344                                                              et voilà nous somme 3 maintenant  je vient donne naissance à un petit garçon tout beau et tout calme
# 106448                                                                                                                                               28. jeux vidéo, F1
# 107904                                           A la recherche de bons plans et de concours.Fan de #JeuxVideos et #Sport. Accessoirement débutant en dessin Allez l'OM
# 111686                                                                                            Vivre est une chose rare. La plupart des gens se contentent d'exister.
# 107683                                                                                                                                      passionné de L'OM et de moto
# 109381                                                                                                                                                   C'est important
# 109359                                                                                            Pas d’place pour une pute qui michtonne et un faux refré qui mythonne.
# 112202                                                                                                         Sème l'excellence tu récolteras l'excellence in sha ALLAH
# 111899                                                                                                                              Animateur/réalisateur/Média planneur
# 108357                                                                                                                            passionné de mangas/animé/jeux vidéos.
# 110394                                                                                                                                           vélotaff  gravel and co
# 108167                                                                Des rencontres autour d'une même passion: les courses hippiques ...Membre @PMU_Hippique et @zeturf
# 107551                                                                                                                                               T'obéis c'est tout.
# 109913                                                                                                                                           Ne va pas bien du tout.

# %% [markdown]
# ### Create income plots

# %%
#Load data
path = '/home/livtollanes/10.jan-thesis/Code/Validation/Data/annotations/'
file = 'onlygreens1.csv'
onlygreens = pd.read_csv(path+file)

#income data
path = '/home/livtollanes/10.jan-thesis/Code/Validation/Data/'
file = 'INSEE_merged.csv'

income = pd.read_csv(path+file, sep=",")

# %%
#Make the codes lower case, to match between data sets
income = income.drop(income.columns[0], axis=1)
income = income.drop('Effectifs en EQTP', axis=1)
income['PCS_ESE'] = income['PCS_ESE'].str.lower()

onlygreens['PCS_ESE'] = onlygreens['PCS_ESE'].str.lower()

#merge the two dfs 
onlygreens = onlygreens.merge(income, on='PCS_ESE', how='left')

# %%
#Check for NA in income codes
na_salaries = onlygreens['Salaire moyen en EQTP'].isna()
associated_pcs_ese = onlygreens.loc[na_salaries, 'PCS_ESE'].unique()
print(associated_pcs_ese) #['100x' '352b' '335a' '22d6' '464b']

#remove rows where income is NA
onlygreens = onlygreens.dropna(subset=['Salaire moyen en EQTP'])

#inspect the rows where duplicates don't have the same job code
duplicates = onlygreens[onlygreens.duplicated('screen_name', keep=False)]
sorted_duplicates = duplicates.sort_values('screen_name')

unique_pcs_ese = sorted_duplicates.groupby('screen_name')['PCS_ESE'].nunique() > 1
screen_names_with_multiple_pcs_ese = sorted_duplicates['screen_name'].isin(unique_pcs_ese.index[unique_pcs_ese])
rows_with_multiple_pcs_ese = sorted_duplicates[screen_names_with_multiple_pcs_ese]
rows_with_multiple_pcs_ese.shape #none. Clear for duplicate deletion

#For the rest of the duplicates, remove keep only the first version
onlygreens = onlygreens.drop_duplicates(subset=['screen_name'], keep='first')
# Out:
# ['100x' '22d6' '335a' '352b' '464b']

# %%
#Create a title column that merges variants of the same key words into its neutral form

# Create a new column 'title' from 'key_word'
onlygreens['title'] = onlygreens['key_word']

# Define a dictionary of words to replace
replace_dict = {'actrice': 'acteur',
'adjointe maire': 'adjoint maire',
'aide soignante': 'aide soignant',
'animateur enfance' : 'animateur socioculturel',
'animateur jeunesse': 'animateur socioculturel',
'animateur périscolaire': 'animateur socioculturel',
'animateur sportif': 'animateur socioculturel',
'animatrice radio': 'animateur radio',
'artiste céramiste': 'artiste plasticien',
'artiste plasticienne': 'artiste plasticien',
'artiste peintre': 'artiste plasticien',
'auteure compositrice interprète': 'auteur compositeur interprète',
'avocate': 'avocat',
'barmaid': 'barman',
'chanteuse': 'chanteur',
'chargé com': 'chargée communication',
'chargée com': 'chargée communication',
'chauffeur poid lourd': 'chauffeur poids lourds',
'chauffeur poids lourd': 'chauffeur poids lourds',
'chercheuse cnrs': 'chercheur',
'chercheur cnrs': 'chercheur',
'chroniqueuse': 'chroniqueur',
'coach sportive': 'coach sportif',
'coach handball': 'coach sportif',
'coach basket': 'coach sportif',
'tennis coach': 'coach sportif',
'entraineur coach': 'coach sportif',
'coiffure': 'coiffeur',
'compositrice': 'compositeur',
'comédienne': 'comédien',
'comédienne metteur scène': 'comédien metteur scène',
'conducteur métro': 'conducteur train métro',
'conducteur train': 'conducteur train métro',
'conducteur sncf': 'conducteur train métro',
'danseuse': 'danseur',
'doctorante': 'doctorant',
'doctorant droit public': 'doctorant',
'doctorant droit': 'doctorant',
'doctorant histoire': 'doctorant',
'doctorant droit': 'doctorant',
'développer': 'développeur',
'développeur web mobile': 'développeur',
'illustratrice': 'illustrateur',
'ingénieure recherche': 'ingénieur recherche',
'musicienne': 'musicien',
'médecin santé publique': 'médecin',
'médecin éducation nationale': 'médecin',
'médecine': 'médecin',
'ouvrière': 'ouvrier',
'responsable com': 'responsable communication',
'rédac chef': 'rédacteur chef',
'red chef': 'rédacteur chef',
'rédac chef adjoint': 'rédacteur chef adjoint',
'rédacteur chef adjoint': 'rédacteur chef adjoint',
'red chef adjointe': 'rédacteur chef adjoint',
'rédactrice chef': 'rédacteur chef',
'rédactrice chef adjointe': 'rédacteur chef adjoint',
'soignante': 'soignant',
'responsable com': 'responsable communication',
'sapeur': 'pompier',
'journalist': 'journaliste',
'agrégé sciences économiques': 'agrégé',
'agrégé droit': 'agrégé',
'assistante direction': 'assistant direction',
'chargé recherche': 'chargée recherche',
'compositeur interprète': 'auteur compositeur interprète',
'chercheuse': 'chercheur'
}

# Use replace function
onlygreens['title'] = onlygreens['title'].replace(replace_dict)

# %%
onlygreens['title'].nunique() # 112
# Out:
# 112

# %%
pd.set_option('display.max_rows', None)
print(onlygreens['title'].value_counts().sort_index())
# Out:
# title
# acteur                                 26
# adjoint maire                         347
# agent commercial                       12
# agent immobilier                       32
# agronome                               25
# agrégé                                  7
# aide domicile                           4
# aide soignant                          34
# analyste financier                      5
# animateur radio                        48
# animateur socioculturel                 6
# architecte                             85
# archiviste                             19
# artisan                                38
# artiste                                23
# artiste                                 1
# artiste plasticien                     82
# assistant direction                    15
# assistant régisseur                     1
# auditeur financier                      3
# auditeur interne                        1
# auteur compositeur                     38
# auteur compositeur interprète          49
# avocat                                617
# barista                                 2
# barman                                 15
# bibliothécaire                         60
# boulanger                               9
# cadre marketing                         1
# chanteur                               41
# chargée communication                 359
# chargée recherche                       5
# chargée relations                      32
# chauffeur poids lourds                  3
# chef produit                           14
# chef projet communication              11
# cheffe bureau                           7
# chercheur                              42
# chroniqueur                           133
# coach sportif                          32
# coiffeur                                8
# communication corporate                18
# compositeur                            24
# comptable                              50
# comédien                               86
# comédien metteur scène                  6
# conducteur routier                      4
# conducteur train métro                 15
# conducteur travaux                      4
# conseiller clientèle                    6
# conseiller commercial                   8
# danseur                                15
# designer graphique                     24
# developer                               7
# directeur artistique                   64
# directeur communication                63
# directeur recherche                    12
# directeur école                         5
# directrice adjointe communication       7
# directrice communication              114
# docteur médecine                        4
# docteur pharmacie                      13
# doctorant                             273
# documentaliste                         54
# développeur                           158
# economiste                             38
# esthéticienne                           7
# grand reporter                         79
# graphiste                              90
# guitariste                             11
# humoriste                              14
# illustrateur                           37
# infirmier                              72
# ingénieur agriculture                   4
# ingénieur cnes                          1
# ingénieur financier                     2
# ingénieur recherche                    16
# jardinier                              11
# journaliste                          5741
# juriste                               330
# manucure                                2
# maquilleuse                             3
# marine                                 10
# maître conférences                    108
# musicien                              112
# médecin                               196
# orthophoniste                          12
# ostéopathe                             28
# ouvrier                                32
# pharmacien                             58
# pompier                                22
# professeur universités                 31
# psychanalyste                          28
# psychologue                            89
# psychomotricien                         2
# pâtissier                              19
# radiologue                              2
# rappeur                                14
# reporter                              123
# responsable affaires publiques         10
# responsable communication             305
# responsable marketing                  31
# responsable relations                  62
# responsable réseaux sociaux             7
# rédacteur chef                        404
# rédacteur chef adjoint                120
# rédacteur web                          20
# sculpteur                               6
# secrétaire médicale                     6
# secrétaire rédaction                   20
# technicien laboratoire                  7
# éducateur sportif                      16
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Calculate the mean of 'projection' and its standard deviation for each job group
grouped = filtered.groupby('title').agg({'0': ['mean', 'std']}).reset_index()

# Sort the jobs by the mean SES and reset index
grouped = grouped.sort_values(('0', 'mean')).reset_index(drop=True)
plt.figure(figsize=(13, 25))  # Adjust the size of the figure

# Plot error bars for each job with a small random jitter added to the y-coordinates
for i in range(grouped.shape[0]):
    jitter = np.random.uniform(-0.3, 0.3)  # adjust the range as needed
    plt.errorbar(x=grouped[('0', 'mean')][i], 
                 y=i + jitter, 
                 xerr=grouped[('0', 'std')][i], 
                 fmt='o')

# Add job labels to each point with reduced text size
for i in range(grouped.shape[0]):
    plt.text(grouped[('0', 'mean')][i], 
             i, 
             grouped['title'][i], 
             ha = 'right', va = 'bottom', fontsize=8)  # Adjust fontsize as needed

plt.xlabel('Mean Projected coordinate (SES?)')
plt.ylabel('Job Title Index')
plt.title('Mean dimension coordinate by Job Title Index')

plt.show()

# %%
# Calculate the mean of 'projection' and its standard deviation for each job group
grouped = filtered.groupby('title').agg({'0': ['mean', 'std'], 'Salaire moyen en EQTP': 'first', 'PCS_ESE': 'first'}).reset_index()

# Extract the first digit of PCS_ESE as the color
grouped['color'] = grouped['PCS_ESE', 'first'].str[0].astype(int)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# Calculate the mean of 'projection' and its standard deviation for each job group
grouped = filtered.groupby('title').agg({'0': ['mean', 'std'], 'Salaire moyen en EQTP': 'first', 'PCS_ESE': 'first'}).reset_index()

# Extract the first digit of PCS_ESE as the color
grouped['color'] = grouped['PCS_ESE', 'first'].str[0].astype(int)

# Define a color map manually
color_map = {2: 'red', 3: 'blue', 4: 'green', 5: 'orange', 6: 'purple'}

# Define a title map manually
title_map = {2: 'Artisans, commerçants et chefs d\'entreprises', 
             3: 'Cadres et professions intellectuelles supérieures', 
             4: 'Professions intermédiaires', 
             5: 'Employés', 
             6: 'Ouvriers'}

plt.figure(figsize=(20, 25))  # Adjust the size of the figure

# Plot error bars for each job with a small random jitter added to the y-coordinates
for i in range(grouped.shape[0]):
    jitter = np.random.uniform(-0.3, 0.6)  
    plt.errorbar(x=grouped[('0', 'mean')][i], 
                 y=grouped[('Salaire moyen en EQTP', 'first')][i] + jitter, 
                 xerr=grouped[('0', 'std')][i], 
                 fmt='o',
                 color=color_map[grouped['color'][i]])

# Add job labels to each point with reduced text size
for i in range(grouped.shape[0]):
    plt.text(grouped[('0', 'mean')][i], 
             grouped[('Salaire moyen en EQTP', 'first')][i], 
             grouped['title'][i], 
             ha = 'right', va = 'bottom', fontsize=7,  # Adjust fontsize as needed
             color=color_map[grouped['color'][i]])

# Create a list of patches for the legend
patches = [mpatches.Patch(color=color, label=f"{class_num}: {title_map[class_num]}") for class_num, color in color_map.items()]

# Add the legend to the plot
plt.legend(handles=patches, title='Class', loc='center left', bbox_to_anchor=(1, 0.5))

plt.xlabel('Mean Projected coordinate (SES?)')
plt.ylabel('Salaire moyen en EQTP')
plt.title('Mean dimension coordinate by Salaire moyen en EQTP')

plt.show()

# %%
#save onlygreens to csv
onlygreens.to_csv('/home/livtollanes/10.jan-thesis/Code/Brand Validation/Data/onlygreens_cleaned.csv', sep = ',')
